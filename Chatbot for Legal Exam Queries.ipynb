# %%
# !pip install numpy==1.21.4
# !pip install spacy==2.3.0
# !python -m spacy download en_core_web_md

import spacy

# Load spaCy model
nlp = spacy.load("en_core_web_md")

# Define the knowledge base
faq_knowledge_base = {
    "What is the syllabus for CLAT 2025?":
        "The CLAT 2025 syllabus includes English, Current Affairs including GK, Legal Reasoning, Logical Reasoning, and Quantitative Techniques.",
    "How many questions are there in the English section?":
        "There are approximately 28–32 questions in the English section.",
    "Give me last year’s cut-off for NLSIU Bangalore.":
        "Last year's cut-off for NLSIU Bangalore was around AIR 114 for general category.",
    "When is the CLAT exam?":
        "CLAT 2025 is tentatively scheduled for December 2024.",
    "What is the duration of the CLAT exam?":
        "The exam duration is 2 hours."
}

# Function to get top N matches based on semantic similarity
def get_top_matches(user_input, knowledge_base, top_n=3):
    user_doc = nlp(user_input)
    results = []
    for question, answer in knowledge_base.items():
        similarity = user_doc.similarity(nlp(question))
        results.append((question, answer, similarity))
    
    # Sort by similarity score in descending order and return top N
    results.sort(key=lambda x: x[2], reverse=True)
    return results[:top_n]

# Main loop for continuous interaction
while True:
    user_input = input("Ask me something about CLAT (type 'quit' to exit): ")
    if user_input.lower() == 'quit':
        print("Exiting the chatbot. Goodbye!")
        break
    elif user_input.strip() == '':
        print("No query provided. Please ask a question about CLAT.")
    else:
        top_matches = get_top_matches(user_input, faq_knowledge_base)
        if top_matches:
            best_answer = top_matches[0][1]
            print("\nBot’s Response:")
            print(best_answer)
            print("\nTop Similar FAQs:")
            for idx, (q, a, score) in enumerate(top_matches, 1):
                print(f"{idx}. {q}")
        else:
            print("No matching FAQs found.")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Requirement already satisfied: numpy==1.21.4 in ./.local/lib/python3.10/site-packages (1.21.4)
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Collecting spacy==2.3.0
#   Using cached spacy-2.3.0.tar.gz (6.0 MB)
#   Installing build dependencies ... error
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> [2205 lines of output]
#       Looking in links: /usr/share/pip-wheels, /usr/share/pip-wheels
#       Collecting setuptools
#         Using cached setuptools-78.1.0-py3-none-any.whl.metadata (6.6 kB)
#       Collecting wheel
#         Using cached wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
#       Collecting cython>=0.25
#         Using cached Cython-3.0.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
#       Collecting cymem<2.1.0,>=2.0.2
#         Using cached cymem-2.0.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.5 kB)
#       Collecting preshed<3.1.0,>=3.0.2
#         Using cached preshed-3.0.9-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.2 kB)
#       Collecting murmurhash<1.1.0,>=0.28.0
#         Using cached murmurhash-1.0.12-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
#       Collecting thinc==7.4.1
#         Using cached thinc-7.4.1.tar.gz (1.3 MB)
#         Preparing metadata (setup.py): started
#         Preparing metadata (setup.py): finished with status 'done'
#       Collecting blis<0.5.0,>=0.4.0 (from thinc==7.4.1)
#         Using cached blis-0.4.1.tar.gz (1.8 MB)
#         Preparing metadata (setup.py): started
#         Preparing metadata (setup.py): finished with status 'done'
#       Collecting wasabi<1.1.0,>=0.0.9 (from thinc==7.4.1)
#         Using cached wasabi-0.10.1-py3-none-any.whl.metadata (28 kB)
#       Collecting srsly<1.1.0,>=0.0.6 (from thinc==7.4.1)
#         Using cached srsly-1.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
#       Collecting catalogue<1.1.0,>=0.0.7 (from thinc==7.4.1)
#         Using cached catalogue-1.0.2-py2.py3-none-any.whl.metadata (13 kB)
#       Collecting numpy>=1.7.0 (from thinc==7.4.1)
#         Using cached numpy-2.2.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#       Collecting plac<1.2.0,>=0.9.6 (from thinc==7.4.1)
#         Using cached plac-1.1.3-py2.py3-none-any.whl.metadata (2.3 kB)
#       Collecting tqdm<5.0.0,>=4.10.0 (from thinc==7.4.1)
#         Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
#       Using cached setuptools-78.1.0-py3-none-any.whl (1.3 MB)
#       Using cached wheel-0.45.1-py3-none-any.whl (72 kB)
#       Using cached Cython-3.0.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#       Using cached cymem-2.0.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (204 kB)
#       Using cached preshed-3.0.9-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (156 kB)
#       Using cached murmurhash-1.0.12-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (124 kB)
#       Using cached catalogue-1.0.2-py2.py3-none-any.whl (16 kB)
#       Using cached numpy-2.2.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#       Using cached plac-1.1.3-py2.py3-none-any.whl (20 kB)
#       Using cached srsly-1.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (369 kB)
#       Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
#       Using cached wasabi-0.10.1-py3-none-any.whl (26 kB)
#       Building wheels for collected packages: thinc, blis
#         Building wheel for thinc (setup.py): started
#         Building wheel for thinc (setup.py): finished with status 'error'
#         error: subprocess-exited-with-error
#
#         × python setup.py bdist_wheel did not run successfully.
#         │ exit code: 1
#         ╰─> [226 lines of output]
#             /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/setuptools/__init__.py:80: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
#             !!
#
#                     ********************************************************************************
#                     Requirements should be satisfied by a PEP 517 installer.
#                     If you are using pip, you can try `pip install --use-pep517`.
#                     ********************************************************************************
#
#             !!
#               dist.fetch_build_eggs(dist.setup_requires)
#             running bdist_wheel
#             running build
#             running build_py
#             creating build
#             creating build/lib.linux-x86_64-cpython-310
#             creating build/lib.linux-x86_64-cpython-310/thinc
#             copying thinc/__init__.py -> build/lib.linux-x86_64-cpython-310/thinc
#             copying thinc/t2t.py -> build/lib.linux-x86_64-cpython-310/thinc
#             copying thinc/_registry.py -> build/lib.linux-x86_64-cpython-310/thinc
#             copying thinc/t2v.py -> build/lib.linux-x86_64-cpython-310/thinc
#             copying thinc/check.py -> build/lib.linux-x86_64-cpython-310/thinc
#             copying thinc/v2v.py -> build/lib.linux-x86_64-cpython-310/thinc
#             copying thinc/misc.py -> build/lib.linux-x86_64-cpython-310/thinc
#             copying thinc/api.py -> build/lib.linux-x86_64-cpython-310/thinc
#             copying thinc/loss.py -> build/lib.linux-x86_64-cpython-310/thinc
#             copying thinc/about.py -> build/lib.linux-x86_64-cpython-310/thinc
#             copying thinc/describe.py -> build/lib.linux-x86_64-cpython-310/thinc
#             copying thinc/exceptions.py -> build/lib.linux-x86_64-cpython-310/thinc
#             copying thinc/i2v.py -> build/lib.linux-x86_64-cpython-310/thinc
#             copying thinc/config.py -> build/lib.linux-x86_64-cpython-310/thinc
#             copying thinc/compat.py -> build/lib.linux-x86_64-cpython-310/thinc
#             copying thinc/rates.py -> build/lib.linux-x86_64-cpython-310/thinc
#             creating build/lib.linux-x86_64-cpython-310/thinc/tests
#             copying thinc/tests/__init__.py -> build/lib.linux-x86_64-cpython-310/thinc/tests
#             copying thinc/tests/test_util.py -> build/lib.linux-x86_64-cpython-310/thinc/tests
#             copying thinc/tests/strategies.py -> build/lib.linux-x86_64-cpython-310/thinc/tests
#             copying thinc/tests/util.py -> build/lib.linux-x86_64-cpython-310/thinc/tests
#             copying thinc/tests/conftest.py -> build/lib.linux-x86_64-cpython-310/thinc/tests
#             copying thinc/tests/test_api_funcs.py -> build/lib.linux-x86_64-cpython-310/thinc/tests
#             copying thinc/tests/test_config.py -> build/lib.linux-x86_64-cpython-310/thinc/tests
#             creating build/lib.linux-x86_64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/__init__.py -> build/lib.linux-x86_64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/test_beam_search.py -> build/lib.linux-x86_64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/test_hash_embed.py -> build/lib.linux-x86_64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/test_linear.py -> build/lib.linux-x86_64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/test_pickle.py -> build/lib.linux-x86_64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/test_feature_extracter.py -> build/lib.linux-x86_64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/test_about.py -> build/lib.linux-x86_64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/test_pooling.py -> build/lib.linux-x86_64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/test_rates.py -> build/lib.linux-x86_64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/test_mem.py -> build/lib.linux-x86_64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/test_affine.py -> build/lib.linux-x86_64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/test_difference.py -> build/lib.linux-x86_64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/test_rnn.py -> build/lib.linux-x86_64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/test_ops.py -> build/lib.linux-x86_64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/test_model.py -> build/lib.linux-x86_64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/test_pytorch_wrapper.py -> build/lib.linux-x86_64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/test_imports.py -> build/lib.linux-x86_64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/test_check_exceptions.py -> build/lib.linux-x86_64-cpython-310/thinc/tests/unit
#             copying thinc/tests/unit/test_loss.py -> build/lib.linux-x86_64-cpython-310/thinc/tests/unit
#             creating build/lib.linux-x86_64-cpython-310/thinc/tests/integration
#             copying thinc/tests/integration/__init__.py -> build/lib.linux-x86_64-cpython-310/thinc/tests/integration
#             copying thinc/tests/integration/test_pickle.py -> build/lib.linux-x86_64-cpython-310/thinc/tests/integration
#             copying thinc/tests/integration/test_basic_tagger.py -> build/lib.linux-x86_64-cpython-310/thinc/tests/integration
#             copying thinc/tests/integration/test_batch_norm.py -> build/lib.linux-x86_64-cpython-310/thinc/tests/integration
#             copying thinc/tests/integration/test_affine_learns.py -> build/lib.linux-x86_64-cpython-310/thinc/tests/integration
#             copying thinc/tests/integration/test_roundtrip_bytes.py -> build/lib.linux-x86_64-cpython-310/thinc/tests/integration
#             copying thinc/tests/integration/test_shape_check.py -> build/lib.linux-x86_64-cpython-310/thinc/tests/integration
#             copying thinc/tests/integration/test_feed_forward.py -> build/lib.linux-x86_64-cpython-310/thinc/tests/integration
#             copying thinc/tests/integration/test_mnist.py -> build/lib.linux-x86_64-cpython-310/thinc/tests/integration
#             creating build/lib.linux-x86_64-cpython-310/thinc/tests/linear
#             copying thinc/tests/linear/__init__.py -> build/lib.linux-x86_64-cpython-310/thinc/tests/linear
#             copying thinc/tests/linear/test_linear.py -> build/lib.linux-x86_64-cpython-310/thinc/tests/linear
#             copying thinc/tests/linear/test_sparse_array.py -> build/lib.linux-x86_64-cpython-310/thinc/tests/linear
#             copying thinc/tests/linear/test_avgtron.py -> build/lib.linux-x86_64-cpython-310/thinc/tests/linear
#             creating build/lib.linux-x86_64-cpython-310/thinc/linear
#             copying thinc/linear/__init__.py -> build/lib.linux-x86_64-cpython-310/thinc/linear
#             creating build/lib.linux-x86_64-cpython-310/thinc/neural
#             copying thinc/neural/pooling.py -> build/lib.linux-x86_64-cpython-310/thinc/neural
#             copying thinc/neural/__init__.py -> build/lib.linux-x86_64-cpython-310/thinc/neural
#             copying thinc/neural/_custom_kernels.py -> build/lib.linux-x86_64-cpython-310/thinc/neural
#             copying thinc/neural/vecs2vec.py -> build/lib.linux-x86_64-cpython-310/thinc/neural
#             copying thinc/neural/vec2vec.py -> build/lib.linux-x86_64-cpython-310/thinc/neural
#             copying thinc/neural/vecs2vecs.py -> build/lib.linux-x86_64-cpython-310/thinc/neural
#             copying thinc/neural/util.py -> build/lib.linux-x86_64-cpython-310/thinc/neural
#             copying thinc/neural/mem.py -> build/lib.linux-x86_64-cpython-310/thinc/neural
#             copying thinc/neural/_lsuv.py -> build/lib.linux-x86_64-cpython-310/thinc/neural
#             copying thinc/neural/train.py -> build/lib.linux-x86_64-cpython-310/thinc/neural
#             creating build/lib.linux-x86_64-cpython-310/thinc/extra
#             copying thinc/extra/wrappers.py -> build/lib.linux-x86_64-cpython-310/thinc/extra
#             copying thinc/extra/__init__.py -> build/lib.linux-x86_64-cpython-310/thinc/extra
#             copying thinc/extra/datasets.py -> build/lib.linux-x86_64-cpython-310/thinc/extra
#             copying thinc/extra/load_nlp.py -> build/lib.linux-x86_64-cpython-310/thinc/extra
#             copying thinc/extra/hpbff.py -> build/lib.linux-x86_64-cpython-310/thinc/extra
#             copying thinc/extra/visualizer.py -> build/lib.linux-x86_64-cpython-310/thinc/extra
#             creating build/lib.linux-x86_64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/__init__.py -> build/lib.linux-x86_64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/elu.py -> build/lib.linux-x86_64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/feature_extracter.py -> build/lib.linux-x86_64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/function_layer.py -> build/lib.linux-x86_64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/resnet.py -> build/lib.linux-x86_64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/model.py -> build/lib.linux-x86_64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/embed.py -> build/lib.linux-x86_64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/layernorm.py -> build/lib.linux-x86_64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/softmax.py -> build/lib.linux-x86_64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/convolution.py -> build/lib.linux-x86_64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/feed_forward.py -> build/lib.linux-x86_64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/relu.py -> build/lib.linux-x86_64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/maxout.py -> build/lib.linux-x86_64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/multiheaded_attention.py -> build/lib.linux-x86_64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/hash_embed.py -> build/lib.linux-x86_64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/encoder_decoder.py -> build/lib.linux-x86_64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/static_vectors.py -> build/lib.linux-x86_64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/selu.py -> build/lib.linux-x86_64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/attention.py -> build/lib.linux-x86_64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/affine.py -> build/lib.linux-x86_64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/mish.py -> build/lib.linux-x86_64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/difference.py -> build/lib.linux-x86_64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/batchnorm.py -> build/lib.linux-x86_64-cpython-310/thinc/neural/_classes
#             copying thinc/neural/_classes/rnn.py -> build/lib.linux-x86_64-cpython-310/thinc/neural/_classes
#             creating build/lib.linux-x86_64-cpython-310/thinc/extra/_vendorized
#             copying thinc/extra/_vendorized/keras_datasets.py -> build/lib.linux-x86_64-cpython-310/thinc/extra/_vendorized
#             copying thinc/extra/_vendorized/__init__.py -> build/lib.linux-x86_64-cpython-310/thinc/extra/_vendorized
#             copying thinc/extra/_vendorized/keras_data_utils.py -> build/lib.linux-x86_64-cpython-310/thinc/extra/_vendorized
#             copying thinc/extra/_vendorized/keras_generic_utils.py -> build/lib.linux-x86_64-cpython-310/thinc/extra/_vendorized
#             creating build/lib.linux-x86_64-cpython-310/thinc/extra/wrapt
#             copying thinc/extra/wrapt/wrappers.py -> build/lib.linux-x86_64-cpython-310/thinc/extra/wrapt
#             copying thinc/extra/wrapt/__init__.py -> build/lib.linux-x86_64-cpython-310/thinc/extra/wrapt
#             copying thinc/extra/wrapt/decorators.py -> build/lib.linux-x86_64-cpython-310/thinc/extra/wrapt
#             copying thinc/extra/wrapt/importer.py -> build/lib.linux-x86_64-cpython-310/thinc/extra/wrapt
#             copying thinc/structs.pyx -> build/lib.linux-x86_64-cpython-310/thinc
#             copying thinc/linalg.pyx -> build/lib.linux-x86_64-cpython-310/thinc
#             copying thinc/typedefs.pyx -> build/lib.linux-x86_64-cpython-310/thinc
#             copying thinc/cpu.pxd -> build/lib.linux-x86_64-cpython-310/thinc
#             copying thinc/linalg.pxd -> build/lib.linux-x86_64-cpython-310/thinc
#             copying thinc/typedefs.pxd -> build/lib.linux-x86_64-cpython-310/thinc
#             copying thinc/structs.pxd -> build/lib.linux-x86_64-cpython-310/thinc
#             copying thinc/__init__.pxd -> build/lib.linux-x86_64-cpython-310/thinc
#             copying thinc/compile_time_constants.pxi -> build/lib.linux-x86_64-cpython-310/thinc
#             copying thinc/structs.cpp -> build/lib.linux-x86_64-cpython-310/thinc
#             copying thinc/typedefs.cpp -> build/lib.linux-x86_64-cpython-310/thinc
#             copying thinc/linalg.cpp -> build/lib.linux-x86_64-cpython-310/thinc
#             copying thinc/linear/serialize.pyx -> build/lib.linux-x86_64-cpython-310/thinc/linear
#             copying thinc/linear/features.pyx -> build/lib.linux-x86_64-cpython-310/thinc/linear
#             copying thinc/linear/avgtron.pyx -> build/lib.linux-x86_64-cpython-310/thinc/linear
#             copying thinc/linear/linear.pyx -> build/lib.linux-x86_64-cpython-310/thinc/linear
#             copying thinc/linear/sparse.pyx -> build/lib.linux-x86_64-cpython-310/thinc/linear
#             copying thinc/linear/features.pxd -> build/lib.linux-x86_64-cpython-310/thinc/linear
#             copying thinc/linear/__init__.pxd -> build/lib.linux-x86_64-cpython-310/thinc/linear
#             copying thinc/linear/serialize.pxd -> build/lib.linux-x86_64-cpython-310/thinc/linear
#             copying thinc/linear/avgtron.pxd -> build/lib.linux-x86_64-cpython-310/thinc/linear
#             copying thinc/linear/sparse.pxd -> build/lib.linux-x86_64-cpython-310/thinc/linear
#             copying thinc/linear/avgtron.cpp -> build/lib.linux-x86_64-cpython-310/thinc/linear
#             copying thinc/linear/features.cpp -> build/lib.linux-x86_64-cpython-310/thinc/linear
#             copying thinc/linear/serialize.cpp -> build/lib.linux-x86_64-cpython-310/thinc/linear
#             copying thinc/linear/sparse.cpp -> build/lib.linux-x86_64-cpython-310/thinc/linear
#             copying thinc/linear/linear.cpp -> build/lib.linux-x86_64-cpython-310/thinc/linear
#             copying thinc/neural/optimizers.pyx -> build/lib.linux-x86_64-cpython-310/thinc/neural
#             copying thinc/neural/ops.pyx -> build/lib.linux-x86_64-cpython-310/thinc/neural
#             copying thinc/neural/_aligned_alloc.pyx -> build/lib.linux-x86_64-cpython-310/thinc/neural
#             copying thinc/neural/cpu.pxd -> build/lib.linux-x86_64-cpython-310/thinc/neural
#             copying thinc/neural/__init__.pxd -> build/lib.linux-x86_64-cpython-310/thinc/neural
#             copying thinc/neural/ops.pxd -> build/lib.linux-x86_64-cpython-310/thinc/neural
#             copying thinc/neural/optimizers.cpp -> build/lib.linux-x86_64-cpython-310/thinc/neural
#             copying thinc/neural/_aligned_alloc.cpp -> build/lib.linux-x86_64-cpython-310/thinc/neural
#             copying thinc/neural/ops.cpp -> build/lib.linux-x86_64-cpython-310/thinc/neural
#             copying thinc/neural/_murmur3.cu -> build/lib.linux-x86_64-cpython-310/thinc/neural
#             copying thinc/neural/_custom_kernels.cu -> build/lib.linux-x86_64-cpython-310/thinc/neural
#             copying thinc/extra/cache.pyx -> build/lib.linux-x86_64-cpython-310/thinc/extra
#             copying thinc/extra/search.pyx -> build/lib.linux-x86_64-cpython-310/thinc/extra
#             copying thinc/extra/mb.pyx -> build/lib.linux-x86_64-cpython-310/thinc/extra
#             copying thinc/extra/eg.pyx -> build/lib.linux-x86_64-cpython-310/thinc/extra
#             copying thinc/extra/cache.pxd -> build/lib.linux-x86_64-cpython-310/thinc/extra
#             copying thinc/extra/mb.pxd -> build/lib.linux-x86_64-cpython-310/thinc/extra
#             copying thinc/extra/__init__.pxd -> build/lib.linux-x86_64-cpython-310/thinc/extra
#             copying thinc/extra/eg.pxd -> build/lib.linux-x86_64-cpython-310/thinc/extra
#             copying thinc/extra/search.pxd -> build/lib.linux-x86_64-cpython-310/thinc/extra
#             copying thinc/extra/mb.cpp -> build/lib.linux-x86_64-cpython-310/thinc/extra
#             copying thinc/extra/search.cpp -> build/lib.linux-x86_64-cpython-310/thinc/extra
#             copying thinc/extra/cache.cpp -> build/lib.linux-x86_64-cpython-310/thinc/extra
#             copying thinc/extra/eg.cpp -> build/lib.linux-x86_64-cpython-310/thinc/extra
#             running build_ext
#             building 'thinc.linalg' extension
#             creating build/temp.linux-x86_64-cpython-310
#             creating build/temp.linux-x86_64-cpython-310/thinc
#             gcc -pthread -B /opt/conda/envs/anaconda-2024.02-py310/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/envs/anaconda-2024.02-py310/include -fPIC -O2 -isystem /opt/conda/envs/anaconda-2024.02-py310/include -fPIC -I/opt/conda/envs/anaconda-2024.02-py310/include/python3.10 -I/tmp/pip-install-tvmppntx/thinc_8fc3270a958241628c77bef92c07d71d/include -I/opt/conda/envs/anaconda-2024.02-py310/include/python3.10 -c thinc/linalg.cpp -o build/temp.linux-x86_64-cpython-310/thinc/linalg.o -O3 -Wno-strict-prototypes -Wno-unused-function
#             cc1plus: warning: command line option ‘-Wno-strict-prototypes’ is valid for C/ObjC but not for C++
#             g++ -pthread -B /opt/conda/envs/anaconda-2024.02-py310/compiler_compat -shared -Wl,-rpath,/opt/conda/envs/anaconda-2024.02-py310/lib -Wl,-rpath-link,/opt/conda/envs/anaconda-2024.02-py310/lib -L/opt/conda/envs/anaconda-2024.02-py310/lib -Wl,-rpath,/opt/conda/envs/anaconda-2024.02-py310/lib -Wl,-rpath-link,/opt/conda/envs/anaconda-2024.02-py310/lib -L/opt/conda/envs/anaconda-2024.02-py310/lib build/temp.linux-x86_64-cpython-310/thinc/linalg.o -o build/lib.linux-x86_64-cpython-310/thinc/linalg.cpython-310-x86_64-linux-gnu.so
#             building 'thinc.structs' extension
#             gcc -pthread -B /opt/conda/envs/anaconda-2024.02-py310/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/envs/anaconda-2024.02-py310/include -fPIC -O2 -isystem /opt/conda/envs/anaconda-2024.02-py310/include -fPIC -I/opt/conda/envs/anaconda-2024.02-py310/include/python3.10 -I/tmp/pip-install-tvmppntx/thinc_8fc3270a958241628c77bef92c07d71d/include -I/opt/conda/envs/anaconda-2024.02-py310/include/python3.10 -c thinc/structs.cpp -o build/temp.linux-x86_64-cpython-310/thinc/structs.o -O3 -Wno-strict-prototypes -Wno-unused-function
#             cc1plus: warning: command line option ‘-Wno-strict-prototypes’ is valid for C/ObjC but not for C++
#             g++ -pthread -B /opt/conda/envs/anaconda-2024.02-py310/compiler_compat -shared -Wl,-rpath,/opt/conda/envs/anaconda-2024.02-py310/lib -Wl,-rpath-link,/opt/conda/envs/anaconda-2024.02-py310/lib -L/opt/conda/envs/anaconda-2024.02-py310/lib -Wl,-rpath,/opt/conda/envs/anaconda-2024.02-py310/lib -Wl,-rpath-link,/opt/conda/envs/anaconda-2024.02-py310/lib -L/opt/conda/envs/anaconda-2024.02-py310/lib build/temp.linux-x86_64-cpython-310/thinc/structs.o -o build/lib.linux-x86_64-cpython-310/thinc/structs.cpython-310-x86_64-linux-gnu.so
#             building 'thinc.typedefs' extension
#             gcc -pthread -B /opt/conda/envs/anaconda-2024.02-py310/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/envs/anaconda-2024.02-py310/include -fPIC -O2 -isystem /opt/conda/envs/anaconda-2024.02-py310/include -fPIC -I/opt/conda/envs/anaconda-2024.02-py310/include/python3.10 -I/tmp/pip-install-tvmppntx/thinc_8fc3270a958241628c77bef92c07d71d/include -I/opt/conda/envs/anaconda-2024.02-py310/include/python3.10 -c thinc/typedefs.cpp -o build/temp.linux-x86_64-cpython-310/thinc/typedefs.o -O3 -Wno-strict-prototypes -Wno-unused-function
#             cc1plus: warning: command line option ‘-Wno-strict-prototypes’ is valid for C/ObjC but not for C++
#             g++ -pthread -B /opt/conda/envs/anaconda-2024.02-py310/compiler_compat -shared -Wl,-rpath,/opt/conda/envs/anaconda-2024.02-py310/lib -Wl,-rpath-link,/opt/conda/envs/anaconda-2024.02-py310/lib -L/opt/conda/envs/anaconda-2024.02-py310/lib -Wl,-rpath,/opt/conda/envs/anaconda-2024.02-py310/lib -Wl,-rpath-link,/opt/conda/envs/anaconda-2024.02-py310/lib -L/opt/conda/envs/anaconda-2024.02-py310/lib build/temp.linux-x86_64-cpython-310/thinc/typedefs.o -o build/lib.linux-x86_64-cpython-310/thinc/typedefs.cpython-310-x86_64-linux-gnu.so
#             building 'thinc.linear.avgtron' extension
#             creating build/temp.linux-x86_64-cpython-310/thinc/linear
#             gcc -pthread -B /opt/conda/envs/anaconda-2024.02-py310/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/envs/anaconda-2024.02-py310/include -fPIC -O2 -isystem /opt/conda/envs/anaconda-2024.02-py310/include -fPIC -I/opt/conda/envs/anaconda-2024.02-py310/include/python3.10 -I/tmp/pip-install-tvmppntx/thinc_8fc3270a958241628c77bef92c07d71d/include -I/opt/conda/envs/anaconda-2024.02-py310/include/python3.10 -c thinc/linear/avgtron.cpp -o build/temp.linux-x86_64-cpython-310/thinc/linear/avgtron.o -O3 -Wno-strict-prototypes -Wno-unused-function
#             cc1plus: warning: command line option ‘-Wno-strict-prototypes’ is valid for C/ObjC but not for C++
#             thinc/linear/avgtron.cpp: In function ‘int __pyx_f_5thinc_6linear_7avgtron_18AveragedPerceptron_update_weight_ftrl(__pyx_obj_5thinc_6linear_7avgtron_AveragedPerceptron*, __pyx_t_5thinc_8typedefs_feat_t, __pyx_t_5thinc_8typedefs_class_t, __pyx_t_5thinc_8typedefs_weight_t, int)’:
#             thinc/linear/avgtron.cpp:7480:48: warning: taking address of packed member of ‘__pyx_t_5thinc_7structs_SparseArrayC’ may result in an unaligned pointer value [-Waddress-of-packed-member]
#              7480 |   __pyx_f_5thinc_6linear_7avgtron_adam_update((&(__pyx_v_feat->curr[__pyx_v_i]).val), (&(__pyx_v_feat->mom1[__pyx_v_i]).val), (&(__pyx_v_feat->mom2[__pyx_v_i]).val), __pyx_v_self->time, (__pyx_v_feat->times[__pyx_v_i]).val, __pyx_v_grad, __pyx_v_self->learn_rate, __pyx_v_self->momentum);
#                   |                                               ~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             thinc/linear/avgtron.cpp:7480:88: warning: taking address of packed member of ‘__pyx_t_5thinc_7structs_SparseArrayC’ may result in an unaligned pointer value [-Waddress-of-packed-member]
#              7480 |   __pyx_f_5thinc_6linear_7avgtron_adam_update((&(__pyx_v_feat->curr[__pyx_v_i]).val), (&(__pyx_v_feat->mom1[__pyx_v_i]).val), (&(__pyx_v_feat->mom2[__pyx_v_i]).val), __pyx_v_self->time, (__pyx_v_feat->times[__pyx_v_i]).val, __pyx_v_grad, __pyx_v_self->learn_rate, __pyx_v_self->momentum);
#                   |                                                                                       ~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             thinc/linear/avgtron.cpp:7480:128: warning: taking address of packed member of ‘__pyx_t_5thinc_7structs_SparseArrayC’ may result in an unaligned pointer value [-Waddress-of-packed-member]
#              7480 |   __pyx_f_5thinc_6linear_7avgtron_adam_update((&(__pyx_v_feat->curr[__pyx_v_i]).val), (&(__pyx_v_feat->mom1[__pyx_v_i]).val), (&(__pyx_v_feat->mom2[__pyx_v_i]).val), __pyx_v_self->time, (__pyx_v_feat->times[__pyx_v_i]).val, __pyx_v_grad, __pyx_v_self->learn_rate, __pyx_v_self->momentum);
#                   |                                                                                                                               ~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             In file included from /opt/conda/envs/anaconda-2024.02-py310/include/python3.10/Python.h:74,
#                              from thinc/linear/avgtron.cpp:4:
#             thinc/linear/avgtron.cpp: In function ‘void __pyx_tp_dealloc_5thinc_6linear_7avgtron_AveragedPerceptron(PyObject*)’:
#             /opt/conda/envs/anaconda-2024.02-py310/include/python3.10/object.h:133:58: error: lvalue required as increment operand
#               133 | #define Py_REFCNT(ob) _Py_REFCNT(_PyObject_CAST_CONST(ob))
#                   |                                                          ^
#             thinc/linear/avgtron.cpp:14186:7: note: in expansion of macro ‘Py_REFCNT’
#             14186 |     ++Py_REFCNT(o);
#                   |       ^~~~~~~~~
#             /opt/conda/envs/anaconda-2024.02-py310/include/python3.10/object.h:133:58: error: lvalue required as decrement operand
#               133 | #define Py_REFCNT(ob) _Py_REFCNT(_PyObject_CAST_CONST(ob))
#                   |                                                          ^
#             thinc/linear/avgtron.cpp:14188:7: note: in expansion of macro ‘Py_REFCNT’
#             14188 |     --Py_REFCNT(o);
#                   |       ^~~~~~~~~
#             error: command '/usr/bin/gcc' failed with exit code 1
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#         ERROR: Failed building wheel for thinc
#         Running setup.py clean for thinc
#         Building wheel for blis (setup.py): started
#         Building wheel for blis (setup.py): still running...
#         Building wheel for blis (setup.py): still running...
#         Building wheel for blis (setup.py): still running...
#         Building wheel for blis (setup.py): still running...
#         Building wheel for blis (setup.py): still running...
#         Building wheel for blis (setup.py): finished with status 'error'
#         error: subprocess-exited-with-error
#
#         × python setup.py bdist_wheel did not run successfully.
#         │ exit code: 1
#         ╰─> [1901 lines of output]
#             BLIS_COMPILER? None
#             /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/setuptools/__init__.py:80: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
#             !!
#
#                     ********************************************************************************
#                     Requirements should be satisfied by a PEP 517 installer.
#                     If you are using pip, you can try `pip install --use-pep517`.
#                     ********************************************************************************
#
#             !!
#               dist.fetch_build_eggs(dist.setup_requires)
#             running bdist_wheel
#             running build
#             running build_py
#             creating build
#             creating build/lib.linux-x86_64-cpython-310
#             creating build/lib.linux-x86_64-cpython-310/blis
#             copying blis/__init__.py -> build/lib.linux-x86_64-cpython-310/blis
#             copying blis/about.py -> build/lib.linux-x86_64-cpython-310/blis
#             copying blis/benchmark.py -> build/lib.linux-x86_64-cpython-310/blis
#             creating build/lib.linux-x86_64-cpython-310/blis/tests
#             copying blis/tests/__init__.py -> build/lib.linux-x86_64-cpython-310/blis/tests
#             copying blis/tests/test_gemm.py -> build/lib.linux-x86_64-cpython-310/blis/tests
#             copying blis/tests/common.py -> build/lib.linux-x86_64-cpython-310/blis/tests
#             copying blis/tests/test_dotv.py -> build/lib.linux-x86_64-cpython-310/blis/tests
#             copying blis/cy.pyx -> build/lib.linux-x86_64-cpython-310/blis
#             copying blis/py.pyx -> build/lib.linux-x86_64-cpython-310/blis
#             copying blis/__init__.pxd -> build/lib.linux-x86_64-cpython-310/blis
#             copying blis/cy.pxd -> build/lib.linux-x86_64-cpython-310/blis
#             running build_ext
#             unix
#             py_compiler gcc
#             {'BLIS_ARCH': 'generic', 'HOSTNAME': 'aa9d42588791', 'SSL_CERT_FILE': '/opt/_internal/certs.pem', 'TERM': 'xterm', 'OLDPWD': '/usr/local/repos/cython-blis', 'LD_LIBRARY_PATH': '/opt/rh/devtoolset-2/root/usr/lib64:/opt/rh/devtoolset-2/root/usr/lib:/usr/local/lib64:/usr/local/lib', 'LS_COLORS': 'no=00:fi=00:di=00;34:ln=00;36:pi=40;33:so=00;35:bd=40;33;01:cd=40;33;01:or=01;05;37;41:mi=01;05;37;41:ex=00;32:*.cmd=00;32:*.exe=00;32:*.com=00;32:*.btm=00;32:*.bat=00;32:*.sh=00;32:*.csh=00;32:*.tar=00;31:*.tgz=00;31:*.arj=00;31:*.taz=00;31:*.lzh=00;31:*.zip=00;31:*.z=00;31:*.Z=00;31:*.gz=00;31:*.bz2=00;31:*.bz=00;31:*.tz=00;31:*.rpm=00;31:*.cpio=00;31:*.jpg=00;35:*.gif=00;35:*.bmp=00;35:*.xbm=00;35:*.xpm=00;35:*.png=00;35:*.tif=00;35:', 'VIRTUAL_ENV': '/usr/local/repos/cython-blis/env3.6', 'PATH': '/usr/local/repos/cython-blis/env3.6/bin:/opt/rh/devtoolset-2/root/usr/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/usr/local/repos/cython-blis/flame-blis', 'BLIS_ARCh': 'generic', 'LANG': 'en_US.UTF-8', 'HOME': '/root', 'SHLVL': '2', 'LANGUAGE': 'en_US.UTF-8', 'BLIS_ARC': 'generic', 'AUDITWHEEL_PLAT': 'manylinux1_x86_64', 'PKG_CONFIG_PATH': '/usr/local/lib/pkgconfig', 'LESSOPEN': '|/usr/bin/lesspipe.sh %s', 'G_BROKEN_FILENAMES': '1', '_': '/usr/local/repos/cython-blis/env3.6/bin/python'}
#             gcc -c /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/config/generic/bli_cntx_init_generic.c -o /tmp/tmpju_0otm7/bli_cntx_init_generic.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/linux-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64
#             gcc -c /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/config/haswell/bli_cntx_init_haswell.c -o /tmp/tmpju_0otm7/bli_cntx_init_haswell.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/linux-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64
#             gcc -c /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/config/penryn/bli_cntx_init_penryn.c -o /tmp/tmpju_0otm7/bli_cntx_init_penryn.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/linux-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64
#             gcc -c /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/config/piledriver/bli_cntx_init_piledriver.c -o /tmp/tmpju_0otm7/bli_cntx_init_piledriver.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/linux-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64
#             gcc -c /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/config/sandybridge/bli_cntx_init_sandybridge.c -o /tmp/tmpju_0otm7/bli_cntx_init_sandybridge.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/linux-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64
#             gcc -c /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/config/steamroller/bli_cntx_init_steamroller.c -o /tmp/tmpju_0otm7/bli_cntx_init_steamroller.o -O3 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/linux-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64
#             gcc -c /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/kernels/zen/1/bli_amaxv_zen_int.c -o /tmp/tmpju_0otm7/bli_amaxv_zen_int.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/linux-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64
#             gcc -c /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/kernels/zen/1/bli_axpyv_zen_int10.c -o /tmp/tmpju_0otm7/bli_axpyv_zen_int10.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/linux-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64
#             gcc -c /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/kernels/zen/1/bli_axpyv_zen_int.c -o /tmp/tmpju_0otm7/bli_axpyv_zen_int.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/linux-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64
#             gcc -c /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/kernels/zen/1/bli_dotv_zen_int10.c -o /tmp/tmpju_0otm7/bli_dotv_zen_int10.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/linux-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64
#             gcc -c /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/kernels/zen/1/bli_dotv_zen_int.c -o /tmp/tmpju_0otm7/bli_dotv_zen_int.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/linux-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64
#             gcc -c /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/kernels/zen/1/bli_dotxv_zen_int.c -o /tmp/tmpju_0otm7/bli_dotxv_zen_int.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/linux-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64
#             gcc -c /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/kernels/zen/1/bli_scalv_zen_int10.c -o /tmp/tmpju_0otm7/bli_scalv_zen_int10.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/linux-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64
#             gcc -c /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/kernels/zen/1/bli_scalv_zen_int.c -o /tmp/tmpju_0otm7/bli_scalv_zen_int.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/linux-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64
#             gcc -c /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/kernels/zen/1f/bli_axpyf_zen_int_8.c -o /tmp/tmpju_0otm7/bli_axpyf_zen_int_8.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/linux-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64
#             gcc -c /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/kernels/zen/1f/bli_dotxf_zen_int_8.c -o /tmp/tmpju_0otm7/bli_dotxf_zen_int_8.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/linux-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64
#             gcc -c /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/kernels/zen/3/bli_gemm_small.c -o /tmp/tmpju_0otm7/bli_gemm_small.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/linux-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64
#             gcc -c /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/kernels/haswell/3/bli_gemm_haswell_asm_d6x8.c -o /tmp/tmpju_0otm7/bli_gemm_haswell_asm_d6x8.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/linux-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64
#             gcc -c /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/kernels/haswell/3/bli_gemm_haswell_asm_d8x6.c -o /tmp/tmpju_0otm7/bli_gemm_haswell_asm_d8x6.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/linux-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64
#             gcc -c /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/kernels/haswell/3/bli_gemmtrsm_l_haswell_asm_d6x8.c -o /tmp/tmpju_0otm7/bli_gemmtrsm_l_haswell_asm_d6x8.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/linux-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64
#             gcc -c /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/kernels/haswell/3/bli_gemmtrsm_u_haswell_asm_d6x8.c -o /tmp/tmpju_0otm7/bli_gemmtrsm_u_haswell_asm_d6x8.o -O3 -mavx2 -mfma -mfpmath=sse -march=core-avx2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/linux-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64
#             gcc -c /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/kernels/sandybridge/3/bli_gemm_sandybridge_asm_d8x4.c -o /tmp/tmpju_0otm7/bli_gemm_sandybridge_asm_d8x4.o -O3 -mavx -mfpmath=sse -march=corei7-avx -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/linux-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64
#             gcc -c /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/kernels/sandybridge/3/bli_gemm_sandybridge_int_d8x4.c -o /tmp/tmpju_0otm7/bli_gemm_sandybridge_int_d8x4.o -O3 -mavx -mfpmath=sse -march=corei7-avx -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/linux-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64
#             gcc -c /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/kernels/penryn/1/bli_axpyv_penryn_int.c -o /tmp/tmpju_0otm7/bli_axpyv_penryn_int.o -O3 -mssse3 -mfpmath=sse -march=core2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/linux-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64
#             gcc -c /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/kernels/penryn/1/bli_dotv_penryn_int.c -o /tmp/tmpju_0otm7/bli_dotv_penryn_int.o -O3 -mssse3 -mfpmath=sse -march=core2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/linux-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64
#             gcc -c /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/kernels/penryn/1f/bli_axpy2v_penryn_int.c -o /tmp/tmpju_0otm7/bli_axpy2v_penryn_int.o -O3 -mssse3 -mfpmath=sse -march=core2 -fPIC -std=c99 -D_POSIX_C_SOURCE=200112L -DBLIS_VERSION_STRING="0.5.1" -DBLIS_IS_BUILDING_LIBRARY -Iinclude/linux-x86_64 -I./frame/3/ -I./frame/ind/ukernels/ -I./frame/1m/ -I./frame/1f/ -I./frame/1/ -I./frame/include -I/tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64
# ...
#                   |             ^~~~~~~~~~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4823:15: warning: ‘bli_is_col_vector’ defined but not used [-Wunused-function]
#              4823 | static bool_t bli_is_col_vector( dim_t m, dim_t n )
#                   |               ^~~~~~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4817:15: warning: ‘bli_is_row_vector’ defined but not used [-Wunused-function]
#              4817 | static bool_t bli_is_row_vector( dim_t m, dim_t n )
#                   |               ^~~~~~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4811:15: warning: ‘bli_is_vector’ defined but not used [-Wunused-function]
#              4811 | static bool_t bli_is_vector( dim_t m, dim_t n )
#                   |               ^~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4805:15: warning: ‘bli_vector_dim’ defined but not used [-Wunused-function]
#              4805 | static bool_t bli_vector_dim( dim_t m, dim_t n )
#                   |               ^~~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4799:15: warning: ‘bli_nonzero_dim’ defined but not used [-Wunused-function]
#              4799 | static bool_t bli_nonzero_dim( dim_t m )
#                   |               ^~~~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4793:15: warning: ‘bli_zero_dim3’ defined but not used [-Wunused-function]
#              4793 | static bool_t bli_zero_dim3( dim_t m, dim_t n, dim_t k )
#                   |               ^~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4787:15: warning: ‘bli_zero_dim2’ defined but not used [-Wunused-function]
#              4787 | static bool_t bli_zero_dim2( dim_t m, dim_t n )
#                   |               ^~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4781:15: warning: ‘bli_zero_dim1’ defined but not used [-Wunused-function]
#              4781 | static bool_t bli_zero_dim1( dim_t m )
#                   |               ^~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4766:15: warning: ‘bli_is_nonunit_diag’ defined but not used [-Wunused-function]
#              4766 | static bool_t bli_is_nonunit_diag( diag_t diag )
#                   |               ^~~~~~~~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4758:13: warning: ‘bli_toggle_conj’ defined but not used [-Wunused-function]
#              4758 | static void bli_toggle_conj( conj_t* conj )
#                   |             ^~~~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4752:15: warning: ‘bli_apply_conj’ defined but not used [-Wunused-function]
#              4752 | static conj_t bli_apply_conj( conj_t conjapp, conj_t conj )
#                   |               ^~~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4734:15: warning: ‘bli_is_noconj’ defined but not used [-Wunused-function]
#              4734 | static bool_t bli_is_noconj( conj_t conj )
#                   |               ^~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4724:15: warning: ‘bli_is_herm_or_symm’ defined but not used [-Wunused-function]
#              4724 | static bool_t bli_is_herm_or_symm( struc_t struc )
#                   |               ^~~~~~~~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4718:15: warning: ‘bli_is_triangular’ defined but not used [-Wunused-function]
#              4718 | static bool_t bli_is_triangular( struc_t struc )
#                   |               ^~~~~~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4700:15: warning: ‘bli_is_general’ defined but not used [-Wunused-function]
#              4700 | static bool_t bli_is_general( struc_t struc )
#                   |               ^~~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4678:15: warning: ‘bli_is_zeros’ defined but not used [-Wunused-function]
#              4678 | static bool_t bli_is_zeros( uplo_t uplo )
#                   |               ^~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4645:13: warning: ‘bli_toggle_side’ defined but not used [-Wunused-function]
#              4645 | static void bli_toggle_side( side_t* side )
#                   |             ^~~~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4634:15: warning: ‘bli_is_right’ defined but not used [-Wunused-function]
#              4634 | static bool_t bli_is_right( side_t side )
#                   |               ^~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4620:13: warning: ‘bli_toggle_trans’ defined but not used [-Wunused-function]
#              4620 | static void bli_toggle_trans( trans_t* trans )
#                   |             ^~~~~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4614:16: warning: ‘bli_trans_toggled_conj’ defined but not used [-Wunused-function]
#              4614 | static trans_t bli_trans_toggled_conj( trans_t trans )
#                   |                ^~~~~~~~~~~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4602:15: warning: ‘bli_extract_conj’ defined but not used [-Wunused-function]
#              4602 | static conj_t bli_extract_conj( trans_t trans )
#                   |               ^~~~~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4596:16: warning: ‘bli_extract_trans’ defined but not used [-Wunused-function]
#              4596 | static trans_t bli_extract_trans( trans_t trans )
#                   |                ^~~~~~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4590:15: warning: ‘bli_does_conj’ defined but not used [-Wunused-function]
#              4590 | static bool_t bli_does_conj( trans_t trans )
#                   |               ^~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4584:15: warning: ‘bli_does_noconj’ defined but not used [-Wunused-function]
#              4584 | static bool_t bli_does_noconj( trans_t trans )
#                   |               ^~~~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4566:15: warning: ‘bli_is_conjtrans’ defined but not used [-Wunused-function]
#              4566 | static bool_t bli_is_conjtrans( trans_t trans )
#                   |               ^~~~~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4560:15: warning: ‘bli_is_conjnotrans’ defined but not used [-Wunused-function]
#              4560 | static bool_t bli_is_conjnotrans( trans_t trans )
#                   |               ^~~~~~~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4554:15: warning: ‘bli_is_trans’ defined but not used [-Wunused-function]
#              4554 | static bool_t bli_is_trans( trans_t trans )
#                   |               ^~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4548:15: warning: ‘bli_is_notrans’ defined but not used [-Wunused-function]
#              4548 | static bool_t bli_is_notrans( trans_t trans )
#                   |               ^~~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4539:14: warning: ‘bli_dt_proj_to_double_prec’ defined but not used [-Wunused-function]
#              4539 | static num_t bli_dt_proj_to_double_prec( num_t dt )
#                   |              ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4533:14: warning: ‘bli_dt_proj_to_single_prec’ defined but not used [-Wunused-function]
#              4533 | static num_t bli_dt_proj_to_single_prec( num_t dt )
#                   |              ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4527:14: warning: ‘bli_dt_proj_to_complex’ defined but not used [-Wunused-function]
#              4527 | static num_t bli_dt_proj_to_complex( num_t dt )
#                   |              ^~~~~~~~~~~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4515:15: warning: ‘bli_dt_prec’ defined but not used [-Wunused-function]
#              4515 | static prec_t bli_dt_prec( num_t dt )
#                   |               ^~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4509:14: warning: ‘bli_dt_domain’ defined but not used [-Wunused-function]
#              4509 | static dom_t bli_dt_domain( num_t dt )
#                   |              ^~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4502:15: warning: ‘bli_is_double_prec’ defined but not used [-Wunused-function]
#              4502 | static bool_t bli_is_double_prec( num_t dt )
#                   |               ^~~~~~~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4495:15: warning: ‘bli_is_single_prec’ defined but not used [-Wunused-function]
#              4495 | static bool_t bli_is_single_prec( num_t dt )
#                   |               ^~~~~~~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4475:15: warning: ‘bli_is_int’ defined but not used [-Wunused-function]
#              4475 | static bool_t bli_is_int( num_t dt )
#                   |               ^~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4469:15: warning: ‘bli_is_constant’ defined but not used [-Wunused-function]
#              4469 | static bool_t bli_is_constant( num_t dt )
#                   |               ^~~~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4436:14: warning: ‘bli_offset_past_alignment’ defined but not used [-Wunused-function]
#              4436 | static siz_t bli_offset_past_alignment( siz_t p, siz_t size )
#                   |              ^~~~~~~~~~~~~~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4430:15: warning: ‘bli_is_unaligned_to’ defined but not used [-Wunused-function]
#              4430 | static bool_t bli_is_unaligned_to( siz_t p, siz_t size )
#                   |               ^~~~~~~~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4424:15: warning: ‘bli_is_aligned_to’ defined but not used [-Wunused-function]
#              4424 | static bool_t bli_is_aligned_to( siz_t p, siz_t size )
#                   |               ^~~~~~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4370:13: warning: ‘bli_toggle_bool’ defined but not used [-Wunused-function]
#              4370 | static void bli_toggle_bool( bool_t* b )
#                   |             ^~~~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4345:15: warning: ‘bli_is_even’ defined but not used [-Wunused-function]
#              4345 | static bool_t bli_is_even( gint_t a )
#                   |               ^~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4340:15: warning: ‘bli_is_odd’ defined but not used [-Wunused-function]
#              4340 | static bool_t bli_is_odd( gint_t a )
#                   |               ^~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4320:16: warning: ‘bli_round_to_mult’ defined but not used [-Wunused-function]
#              4320 | static guint_t bli_round_to_mult( guint_t val, guint_t mult )
#                   |                ^~~~~~~~~~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:4313:15: warning: ‘bli_round’ defined but not used [-Wunused-function]
#              4313 | static double bli_round( double a )
#                   |               ^~~~~~~~~
#             /tmp/pip-install-tvmppntx/blis_61597db0d24d44cdb1fd089573582862/blis/_src/include/linux-x86_64/blis.h:1812:13: warning: ‘bli_obj_init_subpart_from’ defined but not used [-Wunused-function]
#              1812 | static void bli_obj_init_subpart_from( obj_t* a, obj_t* b )
#                   |             ^~~~~~~~~~~~~~~~~~~~~~~~~
#             error: command '/usr/bin/gcc' failed with exit code 1
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#         ERROR: Failed building wheel for blis
#         Running setup.py clean for blis
#       Failed to build thinc blis
#       ERROR: Could not build wheels for thinc, blis, which is required to install pyproject.toml-based projects
#
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × pip subprocess to install build dependencies did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Collecting en-core-web-md==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.8.0/en_core_web_md-3.8.0-py3-none-any.whl (33.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.5/33.5 MB 33.7 MB/s eta 0:00:000:00:010:00:01
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')
# Ask me something about CLAT (type 'quit' to exit):  Clat syllabus 2025
# Bot’s Response:
# The CLAT 2025 syllabus includes English, Current Affairs including GK, Legal Reasoning, Logical Reasoning, and Quantitative Techniques.
#
# Top Similar FAQs:
# 1. What is the syllabus for CLAT 2025?
# 2. When is the CLAT exam?
# 3. What is the duration of the CLAT exam?
